# %%
#Lunes 2/10/2023

#Resumen: Tratamos de compliar un programa externo "Chuck"

'Introduccion:' No es solo compliar un programa hay que tenr las librerias que usa.
Hay paquetes con dependencias de librerias

#Variables de entorno nos iden como funciona  los archvis

Path =$Patch (.....) para que la llame lo anterio y añada algo nuevo.
source.baschcr
echo $Patch :(Para mostrar conetenido de esa variable)
find .-name "*lgr" (lo buscamos)

Para usar gcc ()
- debemos usar esto (Make cc .....-Alsa) o si no se va la del  PC

#Ejemplo 
Programa para compliar archivos de texto 'Chuck'
Linux y source
"https://chuck.stanford.edu/release/"
Es un lenguaje de programación para síntesis de sonido y música en tiempo real creación.


El Makefile nos dice que vamos hacer.

make menuconfig
Buscamos "gcc" en el menu de configuracion de Tina.

Vamos a compliar el programa
lo descomprimimos le cambamios copliadores de c++

#Debe aparecer en la terminal
linux g++ o chuck
Cuando dice que no encuntra estas libreria "cannont file libreria..."

#Para eso buscamos la librerias lib de la t113
Todos los paqueyes que usamos neceitan librerias por eso le decimos donde encontrarlas.
Buscamos en makefile 

(+=)LDFFLGS son opciones para el linked
#(+=) trae lo de antes y le añade algo.
Es una variable de entorno utilizada en sistemas Unix y Linux para especificar opciones adicionales
que se deben pasar al enlazador (el programa que combina varios archivos de objeto para crear un 
ejecutable o una biblioteca compartida) durante el proceso de compilación.


Cuando estás compilando programas desde el código fuente en Linux, a

#Caso donde las aplicaciones no son del sistem7
*No es solo compliar un programa hay que tenr las librerias que usa.
Hay paquetes con dependencias de librerias

Para pasar  a la tarjeta chuck

# %%
#Notas
-No se puede mandar archvios desde el PC a la placa. Procesador diferente el pc es x86.

# %%
#Pasos de instlación:

#Tina linux:
Tina Linux es un sistema de software integrado para productos de hardware inteligente.
que incluye el código fuente del núcleo, los controladores, las herramientas, el middleware 
del sistema y los paquetes de aplicaciones para el desarrollo del sistema Linux.

https://github.com/mangopi-sbc/Tina-Linux

#Clonamos el repositorio "Tina-Linux" desde GitHub en tu sistema local
$ git clone  https://github.com/mangopi-sbc/Tina-Linux.git

#Abrimos carpeta Tina-Linux/
  $ cd Tina-Linux/
  
#Esto inicializa y actualiza todos los submódulos dentro del repositorio principal. 
# Los submódulos son repositorios secundarios que están vinculados al repositorio principal y que 
# se utilizan como dependencias.
  $ git submodule update --init --recursive

  // download the static file
  #descarga un archivo llamado "prebuilt.tar.gz"
  $ wget http://dl.mangopi.org/tina/prebuilt.tar.gz .
  $ tar xzvf prebuilt.tar.gz
  #descarga un archivo llamado "dl.tar"
  $ wget http://dl.mangopi.org/tina/dl.tar .
  $ tar xvf dl.tar
   #descarga un archivo llamado "riscv64-linux-x86_64-20200528.tar.xz"
  $ wget http://dl.mangopi.org/tina/toolchain/riscv64-linux-x86_64-20200528.tar.xz -P ./lichee/brandy-2.0/tools/toolchain/
     #descarga un archivo llamado "gcc-linaro-7.2.1-2017.11-x86_64_arm-linux-gnueabi.tar.xz"
  $ wget http://dl.mangopi.org/tina/toolchain/gcc-linaro-7.2.1-2017.11-x86_64_arm-linux-gnueabi.tar.xz -P ./lichee/brandy-2.0/tools/toolchain/

# %%
#Datos

#GNU 
 Es un proyecto de software libre sistema operativo completamente libre y compatible con Unix.

#------G++ Compilador----(GNU)------
 Este comando se utiliza para compilar programas escritos en C++ o C. Cuando se ejecuta g++, 
toma el código fuente escrito en C++ (o C), lo compila y lo convierte en un programa ejecutable. 

#'Chuck'
Es un lenguaje de programación para síntesis de sonido y música en tiempo real creación.

#Las variables de entorno 
Son valores que se almacenan en el sistema operativo y que pueden ser accedidos por diferentes programas 
y procesos en un sistema informático.
